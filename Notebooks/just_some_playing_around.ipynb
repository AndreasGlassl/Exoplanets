# %%
import pandas as pd
import requests
import json
from bs4 import BeautifulSoup
import matplotlib as plt
import numpy as np

# %%
nasa = pd.read_csv("../data/nasa/exoplanet_nasa_eqt.csv")

# %%
eu = pd.read_csv("../data/exoplanets/exoplanets_eu.csv")

# %%
nasa_list = nasa["pl_name"].to_list()

# %%
eu_list = eu["# name"].to_list()

# %%
eu_but_not_nasa = []
for items in eu_list:
    if items not in nasa_list:
        eu_but_not_nasa.append(items)

eu_but_not_nasa
# Out:
# ['11 Oph b',
#  "1I/'Oumuamua",
#  '1RXS 1609 b',
#  '1RXS J235133.3+312720 b',
#  '1SWASP J1407 b',
#  '2I/Borisov',
#  '2M 0103-55 (AB) b',
#  '2M 0122-24 b',
#  '2M 0219-39 b',
#  '2M 0441+23 b',
#  '2M 1938+46 b',
#  '2M 2140+16 b',
#  '2M 2206-20 b',
#  '2M 2236+4751 b',
#  '2M J2126-81 b',
#  '2M0045+16',
#  '2M0117-34',
#  '2M1207 A',
#  '2M1207 b',
#  '2M1510A a',
#  '2M1510A b',
#  '2MASS J00413538-5621127 A',
#  '2MASS J00413538-5621127 B',
#  '2MASS J0249-0557 (AB) c',
#  '2MASS J0249-0557A',
#  '2MASS J0249-0557B',
#  '2MASS J11011926-7732383 A',
#  '2MASS J11011926-7732383 B',
#  '2MASS J11193254 AB',
#  '2MASS J1155-7919 b',
#  '2MASS J1450-7841 A',
#  '2MASS J1450-7841 B',
#  '2MASS J15344984-2952274 A',
#  '2MASS J15344984-2952274 B',
#  '2MASS J2250+2325 b',
#  '38 Vir b',
#  '4 Uma b',
#  '47 Uma b',
#  '47 Uma c',
#  '47 Uma d',
#  '7 CMA c',
#  '8 Umi b',
#  'AB Dor C b',
#  'AD 3116 b',
#  'AS 205 A b',
#  'BD+20 274 c',
#  'BD+24 4697 b',
#  'BD+26 1888 b',
# ...
