# %%
import pandas as pd
import requests
import json
import matplotlib
# %matplotlib inline

# %%
with open("../data/nasa/names_dict.json") as ja:
    dictionary = json.load(ja)

# %%
with open("../data/final/final_frame.csv") as ag:
    df = pd.read_csv(ag)

# %%
df = df.rename(columns = dictionary)

# %%
df = df.rename(columns = {'pl_eqt':'Planet Equilibrium Temperature'})

# %%
df.to_csv("../data/final/final_frame.csv", index=False)

# %%
with open("../data/combined/main_frame.csv") as ag:
    df = pd.read_csv(ag,low_memory=False)

# %%
df = df.rename(columns = dictionary)

# %%
df = df.rename(columns = {'pl_eqt':'Planet Equilibrium Temperature'})

# %%
df
# Out:
#                 Planet Name       Host Star Name Planet Letter  \
# 0                CoRoT-11 b             CoRoT-11             b
# 1                CoRoT-12 b             CoRoT-12             b
# 2                CoRoT-13 b             CoRoT-13             b
# 3                CoRoT-14 b             CoRoT-14             b
# 4                CoRoT-16 b             CoRoT-16             b
# ...                     ...                  ...           ...
# 4139              HATS-42 b              HATS-42             b
# 4140  OGLE-2017-BLG-1522L b  OGLE-2017-BLG-1522L             b
# 4141              GJ 1132 c              GJ 1132             c
# 4142             HAT-P-11 c             HAT-P-11             c
# 4143             CoRoT-20 c             CoRoT-20             c
#
#      Discovery Method  Controversial Flag  Number of Planets in System  \
# 0             Transit                   0                            1
# 1             Transit                   0                            1
# 2             Transit                   0                            1
# 3             Transit                   0                            1
# 4             Transit                   0                            1
# ...               ...                 ...                          ...
# 4139          Transit                   0                            1
# 4140     Microlensing                   0                            1
# 4141  Radial Velocity                   0                            2
# 4142  Radial Velocity                   0                            2
# 4143  Radial Velocity                   0                            2
#
#       Orbital Period (days)  pl_orbpererr1  pl_orbpererr2  pl_orbperlim  ...  \
# 0                  2.994330       0.000011      -0.000011           0.0  ...
# 1                  2.828042       0.000013      -0.000013           0.0  ...
# 2                  4.035190       0.000030      -0.000030           0.0  ...
# 3                  1.512140       0.000130      -0.000130           0.0  ...
# 4                  5.352270       0.000200      -0.000200           0.0  ...
# ...                     ...            ...            ...           ...  ...
# 4139               2.292102       0.000002      -0.000002           0.0  ...
# 4140                    NaN            NaN            NaN           0.0  ...
# 4141               8.929000       0.010000      -0.010000           0.0  ...
# 4142            3407.000000     360.000000    -190.000000           0.0  ...
# 4143            1675.000000      19.000000     -17.000000           0.0  ...
#
#       star_sp_type  star_age  star_age_error_min  star_age_error_max  \
# 0              F6V      2.00                1.00                1.00
# 1              G2V      6.30                3.10                3.10
# 2              G0V      1.64                1.52                1.52
# 3              F9V      4.20                3.80                3.80
# 4              G5V      6.73                2.80                2.80
# ...            ...       ...                 ...                 ...
# 4139           NaN      3.26                0.80                0.80
# 4140           NaN       NaN                 NaN                 NaN
# 4141          M3.5      5.00                0.00               10.00
# 4142            K4      6.50                4.10                5.90
# 4143           NaN       NaN                 NaN                 NaN
#
#       star_teff  star_teff_error_min  star_teff_error_max  star_detected_disc  \
# 0        6343.0                 72.0                 72.0                 NaN
# 1        5675.0                 80.0                 80.0                 NaN
# 2        5945.0                 90.0                 90.0                 NaN
# 3        6035.0                100.0                100.0                 NaN
# 4        5650.0                100.0                100.0                 NaN
# ...         ...                  ...                  ...                 ...
# 4139     6060.0                120.0                120.0                 NaN
# 4140        NaN                  NaN                  NaN                 NaN
# 4141     3270.0                140.0                140.0                 NaN
# 4142     4780.0                 50.0                 50.0                 NaN
# 4143        NaN                  NaN                  NaN                 NaN
#
#       star_magnetic_field  star_alternate_names
# 0                     NaN                   NaN
# 1                     NaN                   NaN
# 2                     NaN                   NaN
# 3                     NaN                   NaN
# 4                     NaN                   NaN
# ...                   ...                   ...
# 4139                  NaN                   NaN
# 4140                  NaN                   NaN
# 4141                  NaN                   NaN
# 4142                  NaN                   NaN
# 4143                  NaN                   NaN
#
# [4144 rows x 180 columns]

# %%
df.to_csv("../data/combined/main_frame.csv", index=False)
