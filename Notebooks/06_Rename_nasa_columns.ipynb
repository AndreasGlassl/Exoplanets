# %%
import pandas as pd
import requests
import json
import matplotlib
# %matplotlib inline

# %%
with open("../data/nasa/names_dict.json") as ja:
    dictionary = json.load(ja)

# %%
with open("../data/final/final_frame.csv") as ag:
    df = pd.read_csv(ag)

# %%
df = df.rename(columns = dictionary)

# %%
df = df.rename(columns = {'pl_eqt':'Planet Equilibrium Temperature'})

# %%
df["Planet Equilibrium Temperature"] = df["Planet Equilibrium Temperature"] - 273.0

# %%
df.to_csv("../data/final/final_frame.csv", index=False)

# %%
df
# Out:
#      pl_id           Planet Name  Stellar Mass (solar mass)  \
# 0      330         Proxima Cen b                       0.12
# 1      482              GJ 411 b                       0.39
# 2      387            Ross 128 b                       0.17
# 3       35            HD 20794 b                       0.70
# 4       36            HD 20794 c                       0.70
# ..     ...                   ...                        ...
# 778    115           Kepler-40 b                       1.48
# 779    274  OGLE-2005-BLG-071L b                       0.46
# 780    263               WTS-1 b                       1.20
# 781    268   MOA-2007-BLG-400L b                       0.30
# 782    275  OGLE-2005-BLG-390L b                       0.22
#
#      Orbital Period (days)  Effective  Temperature (K)  Distance (pc)  \
# 0                11.186000                      3050.0           1.30
# 1                12.953200                      3563.0           2.55
# 2                 9.865800                      3192.0           3.38
# 3                18.315000                      5401.0           6.00
# 4                40.114000                      5401.0           6.00
# ..                     ...                         ...            ...
# 778               6.873490                      6510.0        2700.00
# 779                    NaN                         NaN        3200.00
# 780               3.352057                      6250.0        3200.00
# 781                    NaN                         NaN        5800.00
# 782            3285.000000                         NaN        6600.00
#
#      Planet Mass or M*sin(i) [Jupiter mass]  Planet Equilibrium Temperature  \
# 0                                   0.00400                          -312.0
# 1                                   0.00941                          -196.0
# 2                                   0.00440                          -245.0
# 3                                   0.00850                           114.0
# 4                                   0.00760                           -38.0
# ..                                      ...                             ...
# 778                                 2.20000                          1074.0
# 779                                 3.80000                          -491.0
# 780                                 4.01000                           954.0
# 781                                 0.83000                          -443.0
# 782                                 0.01700                          -496.0
#
#        st_dist_km  years_by_car  years_by_plane  years_by_rocket    pl_mass_e
# 0    4.014153e+13  3.152806e+07    6.305613e+06     1.563892e+05     1.271200
# 1    7.873916e+13  6.184351e+07    1.236870e+07     3.067635e+05     2.990498
# 2    1.043680e+14  8.197297e+07    1.639459e+07     4.066119e+05     1.398320
# 3    1.852686e+14  1.455141e+08    2.910283e+07     7.217964e+05     2.701300
# 4    1.852686e+14  1.455141e+08    2.910283e+07     7.217964e+05     2.415280
# ..            ...           ...             ...              ...          ...
# 778  8.337087e+16  6.548137e+10    1.309627e+10     3.248084e+08   699.160000
# 779  9.880993e+16  7.760754e+10    1.552151e+10     3.849581e+08  1207.640000
# 780  9.880993e+16  7.760754e+10    1.552151e+10     3.849581e+08  1274.378000
# 781  1.790930e+17  1.406637e+11    2.813273e+10     6.977365e+08   263.774000
# 782  2.037955e+17  1.600656e+11    3.201311e+10     7.939760e+08     5.402600
#
# [783 rows x 13 columns]
