# %%
import pandas as pd
import requests
import json
import matplotlib
# %matplotlib inline

# %%
with open("../data/nasa/names_dict.json") as ja:
    dictionary = json.load(ja)

# %%
with open("../data/nasa/exoplanet_nasa_eqt.csv") as ag:
    df = pd.read_csv(ag)

# %%
df = df.rename(columns = dictionary)

# %%
df = df.rename(columns = {'pl_eqt':'Planet Equilibrium Temperature'})

# %%
df["Planet Equilibrium Temperature"] = df["Planet Equilibrium Temperature"] - 273.0

# %%
df
# Out:
#       Unnamed: 0  Unnamed: 0.1       Host Star Name Planet Letter  \
# 0              0             0             CoRoT-11             b
# 1              1             1             CoRoT-12             b
# 2              2             2             CoRoT-13             b
# 3              3             3             CoRoT-14             b
# 4              4             4             CoRoT-16             b
# ...          ...           ...                  ...           ...
# 4139        4139          4139              HATS-42             b
# 4140        4140          4140  OGLE-2017-BLG-1522L             b
# 4141        4141          4141              GJ 1132             c
# 4142        4142          4142             HAT-P-11             c
# 4143        4143          4143             CoRoT-20             c
#
#                 Planet Name Discovery Method  Controversial Flag  \
# 0                CoRoT-11 b          Transit                   0
# 1                CoRoT-12 b          Transit                   0
# 2                CoRoT-13 b          Transit                   0
# 3                CoRoT-14 b          Transit                   0
# 4                CoRoT-16 b          Transit                   0
# ...                     ...              ...                 ...
# 4139              HATS-42 b          Transit                   0
# 4140  OGLE-2017-BLG-1522L b     Microlensing                   0
# 4141              GJ 1132 c  Radial Velocity                   0
# 4142             HAT-P-11 c  Radial Velocity                   0
# 4143             CoRoT-20 c  Radial Velocity                   0
#
#       Number of Planets in System  Orbital Period (days)  pl_orbpererr1  ...  \
# 0                               1               2.994330       0.000011  ...
# 1                               1               2.828042       0.000013  ...
# 2                               1               4.035190       0.000030  ...
# 3                               1               1.512140       0.000130  ...
# 4                               1               5.352270       0.000200  ...
# ...                           ...                    ...            ...  ...
# 4139                            1               2.292102       0.000002  ...
# 4140                            1                    NaN            NaN  ...
# 4141                            2               8.929000       0.010000  ...
# 4142                            2            3407.000000     360.000000  ...
# 4143                            2            1675.000000      19.000000  ...
#
#       st_massn  Stellar Radius (solar radii)  st_raderr1  st_raderr2  \
# 0            5                          1.37        0.03       -0.03
# 1            5                          1.12        0.10       -0.09
# 2            3                          1.01        0.03       -0.03
# 3            3                          1.21        0.08       -0.08
# 4            2                          1.19        0.14       -0.13
# ...        ...                           ...         ...         ...
# 4139         1                          1.48        0.20       -0.12
# 4140         1                           NaN         NaN         NaN
# 4141         3                          0.21        0.01       -0.01
# 4142         7                          0.68        0.01       -0.01
# 4143         5                           NaN         NaN         NaN
#
#       st_radlim  st_radn  Number of Notes  Date of Last Update  \
# 0           0.0        6                0           2014-05-14
# 1           0.0        6                0           2014-05-14
# 2           0.0        4                0           2014-05-14
# 3           0.0        4                0           2014-05-14
# 4           0.0        3                0           2014-05-14
# ...         ...      ...              ...                  ...
# 4139        0.0        2                0           2018-04-12
# 4140        0.0        0                0           2018-04-12
# 4141        0.0        3                1           2018-06-21
# 4142        0.0        9                0           2019-01-31
# 4143        0.0        5                0           2018-07-19
#
#           Discovery Facility  Planet Equilibrium Temperature
# 0                      CoRoT                          1384.0
# 1                      CoRoT                          1169.0
# 2                      CoRoT                          1427.0
# 3                      CoRoT                          1679.0
# 4                      CoRoT                             NaN
# ...                      ...                             ...
# 4139                HATSouth                          1583.0
# 4140                    OGLE                             NaN
# 4141    La Silla Observatory                            27.0
# 4142  W. M. Keck Observatory                             NaN
# 4143  Multiple Observatories                             NaN
#
# [4144 rows x 85 columns]
